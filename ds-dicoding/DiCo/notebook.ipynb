# %% [markdown]
# # Dicoding Collection (DiCo)

# %% [markdown]
# ## Background

# %% [markdown]
# Dicoding Collection atau sering disingkat DiCo merupakan sebuah perusahaan yang bergerak di bidang fashion. Ia memproduksi berbagai item fashion dan menjualnya melalui platform online.
# ![image.png](attachment:0443f06e-5e29-4b08-8e3e-c9b9f3aca82e.png)
# Sebagai perusahaan kekinian, DiCo menyadari betapa pentingnya data bagi perkembangan sebuah bisnis. Oleh karena itu, ia menyimpan semua history penjualan beserta informasi terkait produk dan customers dalam sebuah database. Database ini terdiri dari empat buah tabel, antara lain customers, orders, products, dan sales.
#
# - Tabel customers: tabel ini menyimpan berbagai informasi terkait customer, seperti customer_id, customer_name, gender, age, home_address, zip_code, city, state, dan country.
# - Tabel orders: tabel ini menyimpan berbagai informasi terkait sebuah order yang terdiri dari order_id, customer_id, order_date, dan delivery_date.
# - Tabel products: tabel ini berisi berbagai informasi terkait sebuah produk, seperti product_id, product_type, product_name, size, colour, price, quantity, dan description.
# - Tabel sales: tabel ini mengandung informasi detail terkait penjualan, seperti sales_id, order_id, product_id, price_per_unit, quantity, dan total_price.

# %% [markdown]
# ## Dataset

# %% [markdown]
# Kita akan menggunakan dataset [DicodingCollection](https://github.com/dicodingacademy/dicoding_dataset/tree/main/DicodingCollection). Ia merupakan hasil modifikasi dari dataset [Shopping Cart Database](https://www.kaggle.com/datasets/ruchi798/shopping-cart-database) yang dipublikasi dalam platform kaggle. Proses modifikasi ini bertujuan untuk memastikan dataset yang digunakan cukup merepresentasikan semua masalah yang umum dijumpai di industri.

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## DATA WRANGLING

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Data yang kita butuhkan tersedia dalam repository dataset Dicoding yang dapat diakses melalui tautan berikut: [DicodingCollection](https://github.com/dicodingacademy/dicoding_dataset/tree/main/DicodingCollection).

# %% [markdown]
# **Catatan:**
# Pada praktik yang umum dijumpai di industri, seluruh data tersebut diperoleh dari proses query database. Proses query ini umumnya dijalankan menggunakan perintah SQL.

# %% [markdown]
# Pada proyek latihan ini data yang akan kita gunakan terdiri dari 4 tabel. Oleh karena itu, pada tahap ini kita akan memuat (load) keempat tabel tersebut.

# %% [markdown]
# #### Memuat tabel customers

# %%
customers_df = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/customers.csv')
customers_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %% [markdown]
# #### Memuat tabel orders

# %%
orders_df = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/orders.csv')
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %% [markdown]
# #### Memuat tabel products

# %%
products_df = pd.read_csv('https://github.com/dicodingacademy/dicoding_dataset/raw/refs/heads/main/DicodingCollection/products.csv')
products_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %% [markdown]
# #### Memuat tabel sales

# %%
sales_df = pd.read_csv('https://github.com/dicodingacademy/dicoding_dataset/raw/refs/heads/main/DicodingCollection/sales.csv')
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Pada proses ini kita akan menilai kualitas dari seluruh data yang akan digunakan. Penilaian ini bertujuan untuk melihat berbagai permasalahan yang ada dalam data tersebut.

# %% [markdown]
# #### Menilai tabel customers_df

# %% [markdown]
# Periksa tipe data dan jumlah non-null tiap kolom dari customers_df.

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %% [markdown]
# INSIGHT: Dari sini terlihat tidak ada masalah pada tipe data. Tetapi, terdapat sedikit perbedaan pada jumlah data pada kolom gender. Hal ini menunjukkan adanya missing values pada kolom gender.

# %% [markdown]
# Untuk memastikannya, jalankan kode berikut untuk memeriksa jumlah missing value pada setiap kolom customers_df.

# %%
customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %% [markdown]
# INSIGHT: Terdapat 18 missing values pada kolom gender di dataframe customers_df.

# %% [markdown]
# Selanjutnya, kita periksa duplikasi data di customers_df.

# %%
print('Jumlah duplikasi:', customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 6

# %% [markdown]
# INSIGHT: terdapat 6 data yang terduplikat. Pada tahap data cleaning nanti, kita akan menghilangkan semua duplikasi tersebut.

# %% [markdown]
# Selanjutnya, kita periksa parameter statistik dari kolom numerik pada customers_df.

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# INSIGHT: terdapat keanehan pada nilai maksimum yang terdapat pada kolom age (tidak mungkin ada orang hidup yang berusia 700 tahun). Ini kemungkinan besar terjadi karena adanya inaccurate value pada kolom tersebut. Masalah ini juga akan kita bersihkan dalam tahap cleaning data.

# %% [markdown]
# #### Menilai tabel orders_df

# %% [markdown]
# Periksa tipe data dan jumlah non-null tiap kolom dari orders_df.

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# INSIGHT: jumlah data pada orders_df telah lengkap, atau dengan kata lain tidak ada missing value di dalamnya. Akan tetapi, terdapat kesalahan tipe data pada kolom order_date dan delivery_date. Kedua kolom tersebut harusnya direpresentasikan sebagai tipe data **datetime**, bukan **object** (ini digunakan untuk tipe data string).

# %% [markdown]
# Berikutnya, kita perlu periksa duplikasi dan ringkasan parameter statistik dari kolom numerik pada orders_df.

# %%
print('Jumlah duplikasi:', orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi: 0
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# INSIGHT: tidak ada duplikasi dan keanehan nilai pada orders_df.

# %% [markdown]
# #### Menilai tabel products_df

# %% [markdown]
# Periksa tipe data dan jumlah non-null tiap kolom dari products_df.

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.3+ KB

# %% [markdown]
# INSIGHT: tidak terlihat ada missing value, dan tidak ada tipe data yang keliru.

# %% [markdown]
# Berikutnya, kita periksa duplikasi dan ringkasan parameter statistik dari kolom numerik pada orders_df.

# %%
print('Jumlah duplikasi:', orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi: 0
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# INSIGHT: tidak ada duplikasi dan keanehan pada nilai data orders_df.

# %% [markdown]
# #### Menilai tabel products_df

# %% [markdown]
# Periksa tipe data beserta jumlah masing-masing non null value kolom tabel products_df.

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.3+ KB

# %% [markdown]
# INSIGHT: tidak ada missing value pada products_df. Selain itu, tidak ditemui kesalahan tipe data dari setiap kolomnya.

# %% [markdown]
# Selanjutnya, kita periksa jumlah duplikasi data dan parameter statistik dari products_df.

# %%
print('Jumlah duplikasi:', products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi: 6
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# INSIGHT: terdapat 6 data yang terduplikasi pada products_df. Pada tahap cleaning data, kita akan menghapus duplikasi tersebut.

# %% [markdown]
# #### Menilai tabel sales_df

# %% [markdown]
# Periksa tipe data dan jumlah non null data pada masing-masing kolom tabel sales_df.

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %% [markdown]
# INSIGHT: dari jumlah non-null kolom data total_price, terlihat bahwa kolom tersebut memiliki missing values. Di luar itu, tidak terlihat ada kesalahan tipe data pada masing-masing kolom sales_df.

# %% [markdown]
# Selanjutnya, periksa jumlah missing values pada masing-masing kolom sales_df.

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %% [markdown]
# INSIGHT: terdapat 19 missing values pada kolom data total_price di sales_df.

# %% [markdown]
# Berikutnya, periksa jumlah duplikasi data dan parameter statistik pada sales_df.

# %%
print('Jumlah duplikasi', sales_df.duplicated().sum())
sales_df.describe()
# Out:
# Jumlah duplikasi 0
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# INSIGHT: tidak ada duplikasi dan keanehan nilai data pada sales_df.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Sekarang kita bersihkan berbagai masalah yang telah teridentifikasi dalam proses assessing data sebelumnya.

# %% [markdown]
# #### Membersihkan customers_df

# %% [markdown]
# Berdasarkan hasil proses assessing data, diketahui bahwa terdapat tiga masalah yang dijumpai dalam customers_df, yaitu duplicated data, missing value, dan inaccurate value. Pada tahap ini, kita akan membersihkan ketiga masalah tersebut.

# %% [markdown]
# ##### Menghilangkan duplicate data

# %%
customers_df.drop_duplicates(inplace=True)

# %% [markdown]
# Setelah nge-drop, kita periksa kembali, apakah masih terdapat duplikasi data pada customers_df.

# %%
print('Jumlah duplikasi:', customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 0

# %% [markdown]
# INSIGHT: data customers_df yang terduplikasi sudah berhasil dihapus dan tidak ada duplikasi data lagi di tabel customers_df.

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Masalah berikutnya yang harus kita tangani adalah missing value pada kolom gender. Secara umum, terdapat tiga metode untuk mengatasi missing value, yaitu dropping, imputation, dan interpolation.
#
# Untuk menentukan metode mana yang akan digunakan, kita perlu melihat data yang mengandung missing value tersebut dengan teknik filtering berikut.

# %%
customers_df[customers_df.gender.isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %% [markdown]
# Kode di atas hanya akan menampilkan baris data yang mengandung missing value pada kolom gender.
#
# INSIGHT: Berdasarkan output dari kode di atas, dapat dilihat bahwa baris data tersebut masih mengandung banyak informasi penting sehingga sayang jika langsung dibuang. Oleh karena itu, pada kasus ini **kita akan menggunakan metode imputation** untuk menangani missing value. (jadi kita tidak drop missing value)
#
# Pada metode imputation, kita akan menggunakan nilai tertentu untuk mengganti missing value. Karena kolom gender merupakan kolom kategorik, kita akan menggunakan nilai yang dominan sebagai pengganti missing value tersebut.
#
# Artinya, sekarang kita perlu identifikasi dulu mana nilai yang dominan dari setiap data kolom gender pada customers_df.

# %%
customers_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %% [markdown]
# INSIGHT: nilai dominan pada kolom gender customers_df adalah 'Prefer not to say'. Jadi, kita akan isi missing value kolom tersebut dengan nilai tersebut.

# %%
customers_df['gender'].fillna(value='Prefer not to say', inplace=True)
# Out:
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2320992021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df['gender'].fillna(value='Prefer not to say', inplace=True)

# %% [markdown]
# Lalu, periksa kembali jumlah missing value dari customers_df guna memastikan data kosongnya sudah berhasil terisi.

# %%
customers_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %% [markdown]
# INSIGHT: missing value pada kolom gender dari customers_df sudah berhasil ditangani dengan menggunakan metode imputation: mengisinya dengan nilai kategorik yang dominan, yaitu 'Prefer not to say'.

# %% [markdown]
# ##### Menangani inaccurate value

# %% [markdown]
# Sekarang kita akan mengatasi masalah inaccurate value pada kolom age. Untuk permulaan, kita perlu melihat baris data yang mengandung inaccurate value tersebut (baris dengan nilai age maksimum).
#
# Caranya pakai teknik filter seperti berikut.

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %% [markdown]
# INSIGHT: berdasarkan data di atas, kita bisa asumsikan bahwa inaccurate value tersebut terjadi karena human error sehingga kelebihan memasukkan nilai nol.
#
# Oleh karena itu, kita perlu mengganti nilainya dengan 70.

# %%
customers_df['age'].replace(customers_df['age'].max(), 70)
# Out:
# 0       30
# 1       69
# 2       59
# 3       67
# 4       30
#         ..
# 1002    59
# 1003    30
# 1004    32
# 1005    30
# 1006    71
# Name: age, Length: 1001, dtype: int64

# %% [markdown]
# Setelah diganti, kita periksa, apakah masih ada outlier di kolom age atau tidak.

# %%
print('Usia maksimum:', customers_df.age.max())
# Out:
# Usia maksimum: 700

# %% [markdown]
# INSIGHT: outlier pada kolom age di customers_df sudah berhasil diganti dengan asumsi nilai yang lebih sesuai (700 diganti menjadi 70)

# %% [markdown]
# #### Membersihkan orders_df

# %% [markdown]
# Setelah tabel customers_df kita bersihkan, selanjutnya kita bersihkan tabel orders_df.

# %% [markdown]
# ##### Memperbaiki tipe data

# %% [markdown]
# Berdasarkan hasil proses assessing data sebelumnya, diketahui bahwa terdapat kesalahan tipe data untuk kolom order_date & delivery_date.
#
# Untuk mengatasinya, kita akan ganti tipe data pada kolom tersebut, menjadi datetime. Proses ini dapat dilakukan menggunakan function to_datetime() yang disediakan oleh library pandas.

# %%
datetime_columns = ['order_date', 'delivery_date']

for column in datetime_columns:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %% [markdown]
# Setelah kode di atas dijalankan, kita cek tipe data kolom orders_df, apakah sudah berubah atau belum.

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %% [markdown]
# INSIGHT: tipe data order_date dan delivery_date di tabel orders_df sudah diganti dari object menjadi datetime.

# %% [markdown]
# #### Membersihkan products_df

# %% [markdown]
# Sekarang kita bersihkan tabel products_df

# %% [markdown]
# ##### Menghapus data duplikat

# %% [markdown]
# Sesuai hasil assessing data sebelumnya, kita mengetahui bahwa terdapat 6 data yang terduplikasi pada products_df.
#
# Untuk mengatasi hal ini, kita perlu membuang data yang sama tersebut dengan menggunakan method drop_duplicates()

# %%
products_df.drop_duplicates(inplace=True)

# %% [markdown]
# Untuk memastikan kode tersebut berjalan sesuai harapan, kita periksa lagi jumlah duplikat products_df.

# %%
print('Jumlah duplikasi:', products_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 0

# %% [markdown]
# INSIGHT: data yang terduplikasi pada products_df sudah berhasil dihapus.

# %% [markdown]
# #### Membersihkan sales_df

# %% [markdown]
# Terakhir, kita bersihkan tabel sales_df.

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Berdasarkan penilaian data sebelumnya, diketahui bahwa terdapat 19 missing value pada kolom total_price.
#
# Untuk mengetahui proses penanganan yang paling sesuai, kita perlu melihat terlebih dahulu baris data yang mengandung missing value tersebut.

# %%
sales_df[sales_df['total_price'].isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %% [markdown]
# Berdasarkan tampilan data di atas, dapat dilihat bahwa nilai total_price merupakan hasil perkalian antara price_per_unit dan quantity. Kita dapat menggunakan pola ini untuk menangani missing value pada kolom total_price.

# %%
sales_df['total_price'] = sales_df['price_per_unit'] * sales_df['quantity']

# %% [markdown]
# Untuk memastikan missing value sudah diganti dengan nilai di atas, kita periksa dengan menjalankan kode berikut.

# %%
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# INSIGHT: missing values pada kolom total_price di sales_df sudah berhasil diisi dengan hasil perkalian value kolom price_per_unit dengan quantity.

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Menentukan Pertanyaan Bisnis

# %% [markdown]
# Pada tahap ini, kita akan mendefinisikan berbagai pertanyaan bisnis yang akan digunakan sebagai kompas dalam proses eksplorasi data.
#
# Untuk menentukan sebuah pertanyaan, kita perlu memahami permasalahan bisnis yang dihadapi terlebih dahulu.
#
# Sebagai perusahaan yang bergerak di bidang online fashion, DiCo perlu mengevaluasi performa penjualan (sales) dan memahami item fashion yang paling banyak dibeli. Selain itu, ia juga perlu lebih memahami pelanggannya (customer) sehingga dapat membuat sebuah strategi campaign yang lebih efisien.
#
# Berdasarkan beberapa masalah tersebut, kita dapat mendefinisikan beberapa pertanyaan bisnis seperti berikut.
# - Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?
# - Produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana demografi pelanggan yang kita miliki?
# - Kapan terakhir pelanggan melakukan transaksi?
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# - Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %% [markdown]
# ### Melakukan Eksplorasi Data

# %% [markdown]
# Selanjutnya, kita melakukan eksplorasi data guna menjawab keenam pertanyaan di atas. Pada tahap ini, mungkin hasil yang diperoleh belum cukup untuk menjawab tersebut secara menyeluruh. Namun, proses ini akan sangat membantu kita untuk mengenal data yang sedang ditangani dan membuat strategi analisis yang paling efisien.

# %% [markdown]
# #### Eksplorasi data customers_df

# %% [markdown]
# Pertama, kita akan mengeksplorasi data customers_df terlebih dahulu. Seperti yang kita ketahui, dataset ini memuat berbagai informasi terkait customer, seperti customer_id, customer_name, gender, age, home_address, zip_code, city, state, dan country.
#
# Sebagai permulaan, kita akan melihat rangkuman parameter statistik dari data customers_df menggunakan method describe().

# %%
customers_df.describe(include='all')
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    50.953047
# std      289.013599           NaN                NaN    30.578437
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN   700.000000
#
#                       home_address     zip_code         city            state  \
# count                         1001  1001.000000         1001             1001
# ...

# %% [markdown]
# INSIGHT: berdasarkan rangkuman di atas, jumlah pelanggan DiCo terhitung sebanyak 1001 orang, dengan rentang usia dari 20 sampai 80 tahun, dengan rata-rata dan standar deviasi 49.89 & 17.65 tahun.
#
# Informasi ini memberikan kita gambaran, bahwa segmentasi pelanggan DiCo cukup luas, mulai dari remaja hingga lanjut usia.

# %% [markdown]
# Selanjutnya, kita coba lihat demografi pelanggan berdasarkan jenis kelamin (gender). Untuk melakukan ini, kita gunakan method groupby() yang diikuti dengan method agg().

# %%
customers_df.groupby(by='gender').agg({
    'customer_id': 'nunique',
    'age': ['max', 'min', 'mean', 'std']
})
# Out:
#                   customer_id  age
#                       nunique  max min       mean        std
# gender
# Female                    115   79  20  49.147826  16.646607
# Male                      143   80  20  51.230769  18.462635
# Prefer not to say         742  700  20  51.179004  33.937933

# %% [markdown]
# INSIGHT: berdasarkan pivot table di atas, dapat dilihat bahwa pelanggan DiCo didominasi oleh jenis kelamin 'prefer not to say'. Di sisi lain, distribusi usia mereka cukup mirip, yakni antara 20 hingga 80 tahun.

# %% [markdown]
# Selanjutnya, kita coba lihat persebaran jumlah pelanggan berdasarkan kota (city) dan negara bagian (state).
#
# Untuk melakukannya kita gunakan method groupby(). Selain itu, agar hasilnya lebih mudal dilihat, kita urutkan nilainya menggunakan method sort_values() secara descending.

# %%
customers_df.groupby('city').customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Aidan         3
# East Sophia        3
# New Ava            3
# Lake Rose          2
# Chloeville         2
#                   ..
# Youngview          1
# Zacharyborough     1
# Andersonchester    1
# Zacshire           1
# Ameliaview         1
# Name: customer_id, Length: 961, dtype: int64

# %%
customers_df.groupby('state').customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# INSIGHT: Berdasarkan hasil di atas, dapat dilihat bahwa persebaran pelanggan kita cukup merata pada setiap kota dan negara bagian. Pelanggan kita paling banyak berada di kota East Aidan, East Sophia, dan New Ava dengan jumlah masing-masing tiga pelanggan. Selain itu, pelanggan kita paling banyak berasal dari negara bagian South Australia.

# %% [markdown]
# Sekarang kita telah memiliki cukup banyak informasi terkait data customers_df. Selanjutnya kita akan melakukan eksplorasi terhadap data orders_df.

# %% [markdown]
# #### Eksplorasi orders_df

# %% [markdown]
# Data kedua yang akan kita eksplor adalah orders_df. Ia mengandung berbagai informasi terkait sebuah order yang terdiri dari order_id, customer_id, order_date, dan delivery_date.
#
# Berdasarkan informasi tersebut, kita bisa membuat sebuah kolom baru untuk memuat waktu pengiriman tiap order. Untuk melakukannya, kita perlu menghitung selisih antar delivery_date dan order_date serta menyimpannya sebagai delivery_time.
#
# Selanjutnya, kita akan menggunakan method apply() untuk melakukan sebuah operasi terhadap setiap elemen dalam sebuah kolom DataFrame atau Series (bentuk satu dimensi dari DataFrame).
#
# Operasi yang akan kita lakukan ialah menghitung jumlah detik dari delivery_time menggunakan method total_seconds(). Nilai tersebut selanjutnya diubah ke dalam satuan hari (dibagi 86400) dan diambil bilangan bulatnya saja.

# %%
delivery_time = orders_df['delivery_date'] - orders_df['order_date']
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df['delivery_time'] = round(delivery_time/86400)
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0

# %% [markdown]
# INSIGHT: kolom baru delivery_time berhasil digabungkan ke tabel orders_df

# %% [markdown]
# Selanjutnya, kita eksplor lagi dengan memeriksa parameter statistik kolom tabel orders_df.

# %%
orders_df.describe(include='all')
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# ...

# %% [markdown]
# INSIGHT: Berdasarkan rangkuman ini, dapat dilihat bahwa rata-rata waktu pengiriman ialah selama 14 hari dengan nilai maksimum 27 hari dan nilai minimum 1 hari.

# %% [markdown]
# Sekarang kita telah memiliki cukup informasi terkait data orders_df, selanjutnya kita akan coba mencari informasi lain dengan **menghubungkan** data tersebut dengan data customers_df.

# %% [markdown]
# #### Eksplorasi data orders_df dan customers_df

# %% [markdown]
# Jika kita perhatikan, pada data orders_df terdapat kolom yang berisi informasi terkait customer id pelanggan yang pernah melakukan order. Informasi ini bisa kita gunakan untuk **mengidentifikasi pelanggan yang belum pernah melakukan order**.
#
# Untuk melakukan ini, kita bisa membuat kolom baru bernama "status" pada tabel customers_df. Kolom tersebut nantinya kita isi dengan nilai "Active" untuk pelanggan yang melakukan order setidaknya sekali dan sebaliknya bernilai "Non Active" untuk pelanggan yang belum pernah melakukan order sama sekali.

# %%
customer_id_in_orders_df = orders_df.customer_id.tolist()
customers_df['status'] = customers_df['customer_id'].apply(lambda x: 'Active' if x in customer_id_in_orders_df else 'Non Active')
customers_df.sample(5)
# Out:
#      customer_id customer_name             gender  age  \
# 826          823     fulan 823  Prefer not to say   41
# 180          181     fulan 181  Prefer not to say   27
# 484          484     fulan 484             Female   43
# 171          172     fulan 172               Male   73
# 872          868     fulan 868  Prefer not to say   28
#
#                   home_address  zip_code                  city  \
# 826    02 Adams ManorSuite 241      4450      South Jaydenfort
# 180  35 Fahey CircuitSuite 014      1017       Port Joshuaside
# 484   792 James PlaceSuite 050      7271  South Cameronborough
# 171     81 Kai TerraceApt. 704      5996         East Scarlett
# 872   682 Alyssa CrestApt. 916      8448      New Charlieville
#
#                             state    country      status
# 826                    Queensland  Australia  Non Active
# 180            Northern Territory  Australia      Active
# 484  Australian Capital Territory  Australia  Non Active
# ...

# %% [markdown]
# INSIGHT: telah dibuat kolom baru yang memberi informasi aktif / tidak aktif nya pelanggan berdasarkan histori orders_df (jika id customer tercatat di tabel orders_df, maka dinyatakan aktif).

# %% [markdown]
# Untuk memperoleh informasi terkait jumlah pelanggan yang berstatus 'Active' dan 'Non Active', kita bisa menggunakan pivot table.

# %%
customers_df.groupby(by='status').customer_id.count()
# Out:
# status
# Active        617
# Non Active    384
# Name: customer_id, dtype: int64

# %% [markdown]
# INSIGHT: berdasarkan tabel pivot ini, terdapat cukup banyak pelanggan yang belum pernah melakukan transaksi sebelumnya. Ini tentunya merupakan kabar buruk bagi kita karena hampir 30% pelanggan kita belum pernah melakukan order sebelumnya.

# %% [markdown]
# Untuk memperoleh lebih banyak informasi terkait customers_df dan orders_df, kita perlu menggabungkan keduanya melalui proses **join** atau **merge**.

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how='left',
    left_on='customer_id',
    right_on='customer_id'
)
orders_customers_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0
#
#   customer_name             gender  age                   home_address  \
# 0      fulan 64  Prefer not to say   75      4927 Alice MeadowApt. 960
# 1     fulan 473               Male   61  531 Schmitt BoulevardApt. 010
# 2     fulan 774  Prefer not to say   34       2096 Wilson MewsApt. 714
# 3     fulan 433  Prefer not to say   46        5777 Mayer PassApt. 881
# 4     fulan 441  Prefer not to say   53   33 Richards JunctionApt. 478
#
#    zip_code                city              state    country  status
# ...

# %% [markdown]
# INSIGHT: Pada kode di atas, kita melakukan proses merge dengan metode “left”. Metode ini memungkinkan kita untuk mengambil semua nilai dari tabel kiri serta nilai yang bersesuaian dengan tabel kanan.

# %% [markdown]
# Ada banyak sekali informasi yang bisa kita eksplor dari data hasil gabungan ini. Berikut beberapa hal yang bisa dijelajahi:

# %% [markdown]
# ##### Jumlah order berdasarkan kota

# %%
orders_customers_df.groupby(by='city').order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2  Port Hannahburgh         5
# 3         Lake Rose         5
# 4        O'keefeton         5
# 5          East Max         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8         Sarahstad         4
# 9        Russelstad         4

# %% [markdown]
# INSIGHT: Berdasarkan hasil tersebut, diketahui bahwa kota Jordanside dan New Ava merupakan dua kota yang memiliki jumlah order terbanyak

# %% [markdown]
# ##### Jumlah order berdasarkan state

# %%
orders_customers_df.groupby(by='state').order_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 148
# Queensland                      139
# Western Australia               130
# New South Wales                 129
# Victoria                        118
# Australian Capital Territory    118
# Tasmania                        112
# Northern Territory              106
# Name: order_id, dtype: int64

# %% [markdown]
# INSIGHT: Berdasarkan pivot table tersebut, diketahui bahwa South Australia merupakan state yang balik banyak melakukan order.

# %% [markdown]
# ##### Jumlah order berdasarkan gender

# %%
orders_customers_df.groupby('gender').order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    725
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %% [markdown]
# INSIGHT: Berdasarkan hasil tersebut, dapat dilihat bahwa kebanyakan order dilakukan oleh pelanggan yang berjenis kelamin prefer not to say. Hal ini tentunya sejalan dengan jumlah pelanggan yang kebanyakan dari kelompok gender tersebut.

# %% [markdown]
# ##### Jumlah order berdasarkan kelompok usia

# %% [markdown]
# Kita juga bisa mengeksplorasi jumlah order berdasarkan kelompok usia. Untuk melakukan hal ini, kita perlu mendefinisikan sebuah kolom baru bernama “age_group”. Kolom ini akan membantu kita dalam mengelompokkan pelanggan ke dalam tiga kelompok, yaitu youth, adults, dan seniors. Selanjutnya, buat pivot table berdasarkan hal tersebut menggunakan kode di bawah ini.

# %%
orders_customers_df['age_group'] = orders_customers_df['age'].apply(lambda x: 'Youth' if x <= 24 else ('Seniors' if x >64 else 'Adults' ))
orders_customers_df.groupby(by='age_group').order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     681
# Seniors    226
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# INSIGHT: Berdasarkan hasil tersebut diketahui bahwa pelanggan yang paling banyak melakukan order berasal dari kelompok usia Adults.

# %% [markdown]
# Sejauh ini kita telah menemukan banyak sekali informasi yang tentunya menarik untuk ditelusuri lebih dalam. Namun, sebelum itu mari kita mengeksplorasi dua data yang lain (product_df dan sales_df) terlebih dahulu.

# %% [markdown]
# #### Eksplorasi data products_df dan sales_df

# %% [markdown]
# Pada tahap ini, kita akan mengeksplorasi data product_df dan sales_df. Sebagai permulaan, kita dapat melihat rangkuman parameter statistik dari keduanya.

# %%
products_df.describe(include='all')
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                        description
# ...

# %%
sales_df.describe(include='all')
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# INSIGHT: Berdasarkan hasil tersebut, dapat dilihat bahwa harga barang yang dijual berkisar antara 90 hingga 119 dolar. Selain itu, kita juga memperoleh informasi lain yang tidak kalah menarik yaitu pada setiap transaksi pelanggan paling banyak membeli tiga buah item dalam satu jenis produk dengan total harga sebesar 357 dolar.

# %% [markdown]
# Selanjutnya, selidiki produk yang memiliki harga termahal dan terendah.

# %%
products_df.sort_values(by='price', ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 671          665       Jacket        Parka   XS     red    119        65
# 672          666       Jacket        Parka    S     red    119        66
# 673          667       Jacket        Parka    M     red    119        56
# 674          668       Jacket        Parka    L     red    119        73
# 675          669       Jacket        Parka   XL     red    119        64
# ...          ...          ...          ...  ...     ...    ...       ...
# 1222        1216     Trousers      Pleated    S  indigo     90        41
# 1229        1223     Trousers      Pleated    L  violet     90        48
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1226        1220     Trousers      Pleated   XS  violet     90        58
#
#                                         description
# ...

# %% [markdown]
# INSIGHT: Dapat dilihat bahwa produk termahal ialah item jaket bernama Parka dan yang termurah adalah Bomber.

# %% [markdown]
# Selanjutnya, kita cari informasi terkait produk berdasarkan tipe dan nama produknya.

# %%
products_df.groupby(by='product_type').agg({
    'product_id': 'nunique',
    'quantity': 'sum',
    'price': ['min', 'max']
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
products_df.groupby(by='product_name').agg({
    'product_id': 'nunique',
    'quantity': 'sum',
    'price': ['min', 'max']
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# ...

# %% [markdown]
# Pivot table di atas dapat memberikan kita gambaran terkait produk yang dijual oleh Dicoding Collection. Tentunya kita penasaran dengan produk yang paling laris. Untuk menjawab pertanyaan ini, kita perlu menyatukan (merge) tabel product_df dan sales_df dengan kode berikut.

# %%
sales_products_df = pd.merge(
    left=sales_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_products_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# ...

# %% [markdown]
# INSIGHT: Jika diperhatikan kembali, hasil dari proses merge di atas memiliki perbedaan antara nilai price_per_unit dan price. Hal ini bisa terjadi karena adanya potongan harga, biaya operasional, dan biaya lainnya.

# %% [markdown]
# Sekarang kita coba melihat informasi penjualan produk berdasarkan tipenya.

# %%
sales_products_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %% [markdown]
# INSIGHT: Trousers merupakan tipe produk yang paling laris. Akan tetapi, jika dilihat berdasarkan revenue yang diterima, Jacket merupakan tipe produk yang paling banyak menyumbang revenue perusahaan.

# %% [markdown]
# Kita bisa membuat pivot table yang sama untuk melihat informasi penjualan berdasarkan nama produk menggunakan kode di bawah ini.

# %%
sales_products_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# ...

# %% [markdown]
# INSIGHT: Berdasarkan pivot table tersebut, diketahui bahwa produk Denim merupakan produk yang paling laris dan juga paling banyak menyumbang revenue terhadap perusahaan.

# %% [markdown]
# #### Eksplorasi data all_df

# %% [markdown]
# Jika diperhatikan data penjualan ini cukup menarik untuk ditelusuri lebih dalam. Hal ini dilakukan guna melihat pola pembelian berdasarkan demografi pelanggan. Oleh karena itu, kita perlu membuat sebuah DataFrame baru bernama all_df untuk menampung semua informasi dari keempat tabel yang kita miliki. Berikut kode yang dapat kita gunakan untuk menjalankan proses penggabungan ini.

# %%
all_df = pd.merge(
    left=sales_products_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender age               home_address  zip_code            city  \
# ...

# %% [markdown]
# Selanjutnya, mari kita coba lihat preferensi pembelian berdasarkan state pelanggan dan tipe produk menggunakan kode di bawah ini.

# %%
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# ...

# %% [markdown]
# INSIGHT: Pivot table di atas memberikan kita gambaran terkait tipe produk yang disukai pengguna berdasarkan lokasi negara bagiannya. Jika diperhatikan, tipe produk Jacket (garis merah) paling banyak terjual pada negara bagian Queensland, South Australia, dan New South Wales. Untuk tipe produk lain, kita bisa melihatnya pada gambar pivot table di atas.

# %% [markdown]
# Sekarang kita bisa melakukan hal yang sama untuk mengetahui selera tipe produk pelanggan berdasarkan gender dan kelompok usia.

# %%
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2382       255085
#                   Shirt               2404       246515
#                   Trousers            2426       245808

# %%
all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2292       245055
#           Shirt               2225       227781
#           Trousers            2272       231271
# Seniors   Jacket               777        82959
#           Shirt                733        74977
#           Trousers             766        77471
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %% [markdown]
# INSIGHT: pivot table di atas dapat memberikan kita gambaran terkait selera tipe produk pelanggan berdasarkan gender dan kelompok usia. Semua informasi ini akan sangat membantu dalam menjawab pertanyaan terkait preferensi pengguna berdasarkan demografinya.

# %% [markdown]
# Sejauh ini kita telah melakukan eksplorasi terhadap dataset yang kita miliki. Namun, masih banyak pertanyaan analisis atau bisnis yang belum terjawab. Kita akan menggunakan teknik visualisasi dan melakukan analisis data yang lebih advance guna menjawab pertanyaan bisnis yang belum terjawab tersebut.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# Pada tahap ini kita akan fokus menjawab berbagai pertanyaan bisnis yang sebelumnya telah kita buat.
#
# Pada Exploratory Data Analysis, kita telah mendefinisikan beberapa pertanyaan bisnis seperti berikut.
#
# 1. Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?
# 2. Produk apa yang paling banyak dan paling sedikit terjual?
# 3. Bagaimana demografi pelanggan yang kita miliki?
# 4. Kapan terakhir pelanggan melakukan transaksi?
# 5. Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# 6. Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?
#
# Tugas kita sekarang adalah membuat visualisasi data dan explanatory analysis guna menjawab berbagai pertanyaan tersebut.

# %% [markdown]
# ### Bagaimana Performa Penjualan dan Revenue Perusahaan dalam Beberapa Bulan Terakhir?

# %% [markdown]
# Untuk menjawab pertanyaan pertama, kita perlu membuat sebuah DataFrame baru untuk menampung informasi terkait jumlah order dan total revenue yang diperoleh pada tiap bulannya. Oleh karena itu, kita perlu mengubah frekuensi dari data yang awalnya harian menjadi bulanan.
#
# Seperti biasa, library tercinta kita yaitu pandas telah menyediakan sebuah method bernama resample(). Method ini memungkinkan kita untuk mengubah frekuensi atau melakukan resampling terhadap DataFrame yang memiliki komponen time series. Untuk menggunakan method ini, kita harus mendefinisikan parameter rule (mengatur target konversi) dan on (nama kolom bertipe datetime yang akan diubah frekuensinya).
#
# **Catatan tambahan:** Apa bedanya dengan groupby()?
# - groupby() digunakan untuk mengelompokkan data berdasarkan kategori atau nilai tertentu (misalnya kolom string, angka, atau waktu).
# - resample() khusus untuk time series, digunakan untuk mengelompokkan data berdasarkan interval waktu dengan fleksibilitas tinggi.

# %% [markdown]
# Berikut contoh kode untuk mengubah frekuensi data untuk memperoleh informasi terkait jumlah order dan total revenue yang diperoleh setiap bulannya.

# %%
monthly_orders_df = all_df.resample(rule='ME', on='order_date').agg({
    'order_id': 'nunique',
    'total_price': 'sum'
})
monthly_orders_df
# Out:
#             order_id  total_price
# order_date
# 2021-01-31       109       119333
# 2021-02-28        93        95080
# 2021-03-31       117       131364
# 2021-04-30        99        97530
# 2021-05-31        84        85597
# 2021-06-30       102       101458
# 2021-07-31       105       116081
# 2021-08-31       106       104565
# 2021-09-30        98        96526
# 2021-10-31        80        84266

# %% [markdown]
# Ganti format penulisan tanggal order_date, dari y-m-d menjadi y-m

# %%
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df
# Out:
#             order_id  total_price
# order_date
# 2021-01          109       119333
# 2021-02           93        95080
# 2021-03          117       131364
# 2021-04           99        97530
# 2021-05           84        85597
# 2021-06          102       101458
# 2021-07          105       116081
# 2021-08          106       104565
# 2021-09           98        96526
# 2021-10           80        84266

# %% [markdown]
# order_date jangan jadi index, jadi kita reset_index()

# %%
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df
# Out:
#   order_date  order_id  total_price
# 0    2021-01       109       119333
# 1    2021-02        93        95080
# 2    2021-03       117       131364
# 3    2021-04        99        97530
# 4    2021-05        84        85597
# 5    2021-06       102       101458
# 6    2021-07       105       116081
# 7    2021-08       106       104565
# 8    2021-09        98        96526
# 9    2021-10        80        84266

# %% [markdown]
# Nama kolom order_id sama total_price kurang sesuai untuk data yang baru ini. Kita rename:

# %%
monthly_orders_df.rename(columns={
    'order_id': 'order_count',
    'total_price': 'revenue'
}, inplace=True)
monthly_orders_df
# Out:
#   order_date  order_count  revenue
# 0    2021-01          109   119333
# 1    2021-02           93    95080
# 2    2021-03          117   131364
# 3    2021-04           99    97530
# 4    2021-05           84    85597
# 5    2021-06          102   101458
# 6    2021-07          105   116081
# 7    2021-08          106   104565
# 8    2021-09           98    96526
# 9    2021-10           80    84266

# %% [markdown]
# INSIGHT: data untuk memperoleh informasi terkait jumlah order dan total revenue yang diperoleh tiap bulan sudah siap digunakan untuk menjawab pertanyaan.

# %% [markdown]
# Sekarang kita bisa bikin line chart nya pakai dataframe baru kita tadi: monthly_orders_df

# %%
plt.figure(figsize=(10,5))
plt.plot(monthly_orders_df['order_date'], monthly_orders_df['order_count'], marker='o', linewidth=2, color="#72BCD4")
plt.title('Number of Orders per Month (2021)')
plt.show()

# %% [markdown]
# INSIGHT: berdasarkan grafik di atas, dapat dilihat bahwa jumlah order terbanyak terjadi pada bulan Februari. Sementara itu, kita juga dapat melihat adanya penurunan jumlah order yang cukup signifikan pada bulan Februari, April, Mei, dan Oktober.
#
# Tentunya penurunan jumlah order tersebut akan berdampak pada total revenue yang diperoleh perusahaan. Untuk memvalidasi hal ini, kita buat line chart untuk revenue per bulan berikut.

# %%
plt.figure(figsize=(10,5))
plt.plot(
    monthly_orders_df['order_date'],
    monthly_orders_df['revenue'],
    marker='o',
    linewidth=2,
    color='#72BCD4'
)
plt.title('Total Revenue per Month (2021)', loc='center', fontsize=20)
plt.show()

# %% [markdown]
# INSIGHT: Penurunan jumlah orderan yang sangat signifikan terjadi pada bulan Februari, April, Mei, dan Oktober berdampak terhadap penurunan revenue perusahaan. Normalnya, kita harus mencari tahu penyebab terjadinya penurunan tersebut dengan mempertimbangkan banyak hal, seperti keberadaan kompetitor, campaign, dll. Namun, untuk studi kasus ini, kita tidak memiliki cukup informasi terkait hal tersebut.

# %% [markdown]
# ### Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?

# %% [markdown]
# Pada pertanyaan bisnis selanjutnya, kita ingin mengidentifikasi produk dengan penjualan terbanyak dan paling sedikit. Untuk melakukan ini, tentunya kita harus membuat sebuah DataFrame baru guna menampung informasi terkait jumlah penjualan tiap produk. Berikut merupakan contoh kode untuk melakukannya.

# %%
sum_order_items_df = all_df.groupby('product_name').quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head()
# Out:
#       product_name  quantity_x
# 0            Denim         527
# 1          Joggers         334
# 2          Pleated         308
# 3  Casual Slim Fit         306
# 4        Shearling         302

# %% [markdown]
# Untuk mempermudah kita dalam menyampaikan informasi tersebut, kita harus membuat visualisasi data dalam bentuk bar chart. Selain itu, untuk mempermudah orang lain dalam mengidentifikasi produk dengan performa terbaik dan terburuk, kita perlu membuat dua buah visualisasi data dalam satu gambar visual. Untuk melakukan ini, kita gunakan function subplot().

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))

# %% [markdown]
# Kode tersebut akan menghasilkan kanvas kosong dengan object berupa fig dan ax seperti di atas.

# %% [markdown]
# Selanjutnya, tentunya kita harus mengisi kanvas kosong tersebut dengan bar chart.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x='quantity_x', y='product_name', data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_title('Best Performing Product', loc='center', fontsize=15)

sns.barplot(x='quantity_x', y='product_name', data=sum_order_items_df.sort_values(by='quantity_x', ascending=True).head(), palette=colors, ax=ax[1])
ax[1].set_title('Worst Performing Product', loc='center', fontsize=15)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position('right')
ax[1].yaxis.tick_right()

plt.suptitle('Best and Worst Performing Product by Number of Sales', fontsize=20)
plt.show()
# Out:
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2907320362.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quantity_x', y='product_name', data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2907320362.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quantity_x', y='product_name', data=sum_order_items_df.sort_values(by='quantity_x', ascending=True).head(), palette=colors, ax=ax[1])

# %% [markdown]
# INSIGHT: produk Denim merupakan produk yang paling laris. Kontras dengan hal tersebut, produk Mandarin Collar merupakan produk yang paling sedikit terjual.

# %% [markdown]
# ### Bagaimana Demografi Pelanggan yang Kita Miliki?

# %% [markdown]
# Pertanyaan selanjutnya yang ingin kita jawab ialah terkait demografi pelanggan yang kita miliki. Untuk menjawab hal ini, tentunya kita bisa membuat DataFrame baru untuk menampung informasi terkait jumlah pelanggan untuk demografi tertentu seperti gender, state, dll.

# %% [markdown]
# #### Berdasarkan gender

# %%
bygender_df = all_df.groupby(by='gender').customer_id.nunique().reset_index()
bygender_df.rename(columns={
    'customer_id': 'customer_count'
}, inplace=True)

plt.figure(figsize=(10,5))

sns.barplot(
    y='customer_count',
    x='gender',
    data=bygender_df.sort_values(by='customer_count', ascending=False),
    palette=colors
)

plt.title('Number of Customer by Gender', loc='center')
plt.xlabel(None)
plt.ylabel(None)
plt.show()
# Out:
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2058006831.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2058006831.py:8: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# INSIGHT: Berdasarkan gambar di atas, diketahui bahwa kebanyakan pelanggan tidak bersedia untuk memberitahukan informasi terkait gender-nya.

# %% [markdown]
# #### Berdasarkan age

# %% [markdown]
# Untuk melihat demografi pelanggan berdasarkan usia, kita bisa mengelompokkannya sesuai kelompok usia.

# %%
byage_df = all_df.groupby(by='age_group').customer_id.nunique().reset_index()
byage_df.rename(columns={
    'customer_id': 'customer_count'
}, inplace=True)
byage_df
# Out:
#   age_group  customer_count
# 0    Adults             416
# 1   Seniors             145
# 2     Youth              55

# %% [markdown]
# Bikin urutan kategoris age_group jadi Youth - Adults - Seniors

# %%
byage_df['age_group'] = pd.Categorical(byage_df['age_group'], ['Youth', 'Adults', 'Seniors'])
byage_df
# Out:
#   age_group  customer_count
# 0    Adults             416
# 1   Seniors             145
# 2     Youth              55

# %%
plt.figure(figsize=(10,5))

colors_=["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    y='customer_count',
    x='age_group',
    data=byage_df.sort_values(by='age_group', ascending=False),
    palette=colors_
)

plt.title('Number of Customer by Age', loc='center', fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)

plt.show()
# Out:
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\17810666.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\17810666.py:5: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# INSIGHT: pelanggan yang kita miliki didominasi oleh kelompok usia dewasa.

# %% [markdown]
# #### Berdasarkan states

# %% [markdown]
# Selain berdasarkan gender dan age, kita juga bisa melihat demografi pelanggan berdasarkan states atau negara bagiannya.

# %%
bystate_df = all_df.groupby(by='state').customer_id.nunique().reset_index()
bystate_df
# Out:
#                           state  customer_id
# 0  Australian Capital Territory           73
# 1               New South Wales           77
# 2            Northern Territory           75
# 3                    Queensland           79
# 4               South Australia           90
# 5                      Tasmania           67
# 6                      Victoria           75
# 7             Western Australia           80

# %%
bystate_df.rename(columns={
    'customer_id': 'customer_count'
}, inplace=True)
bystate_df
# Out:
#                           state  customer_count
# 0  Australian Capital Territory              73
# 1               New South Wales              77
# 2            Northern Territory              75
# 3                    Queensland              79
# 4               South Australia              90
# 5                      Tasmania              67
# 6                      Victoria              75
# 7             Western Australia              80

# %%
plt.figure(figsize=(10,6))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x='customer_count',
    y='state',
    data=bystate_df.sort_values(by='customer_count', ascending=False),
    palette=colors_
)
plt.title('Number of Customer by States', loc='center')
plt.xlabel(None)
plt.ylabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\301446333.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# INSIGHT: Berdasarkan visualisasi data tersebut, dapat diketahui bahwa pelanggan yang kita miliki paling banyak berasal dari negara bagian South Australia.

# %% [markdown]
# Sebenarnya, Anda masih dapat mengidentifikasi demografi pelanggan berdasarkan kategori tertentu. Namun, untuk studi kasus ini, kita hanya akan melihat demografi pelanggan berdasarkan tiga kategori tersebut.

# %% [markdown]
# ### RFM Analysis

# %% [markdown]
# Untuk menjawab tiga pertanyaan analisis terakhir, kita bisa menggunakan teknik analisis lanjutan yang bernama RFM analysis. Sederhananya, RFM analysis merupakan salah satu metode yang umum digunakan untuk melakukan segmentasi pelanggan (mengelompokkan pelanggan ke dalam beberapa kategori) berdasarkan tiga parameter, yaitu recency, frequency, dan monetary.
#
# - Recency: parameter yang digunakan untuk melihat kapan terakhir seorang pelanggan melakukan transaksi.
# - Frequency: parameter ini digunakan untuk mengidentifikasi seberapa sering seorang pelanggan melakukan transaksi.
# - Monetary: parameter terakhir ini digunakan untuk mengidentifikasi seberapa besar revenue yang berasal dari pelanggan tersebut.
#
# Berdasarkan tiga parameter tersebut, kita bisa mengidentifikasi pelanggan mana yang memiliki high value (sering melakukan transaksi dan menghasilkan revenue yang besar) dan low value.
#
# Untuk melakukan RFM analysis, kita perlu membuat sebuah DataFrame untuk menampung informasi terkait tiga parameter tersebut. Berikut contoh kode yang dapat Anda gunakan untuk memperoleh informasi terkait recency, frequency, dan monetary.

# %%
rfm_df = all_df.groupby(by='customer_id', as_index=False).agg({
    "order_date": 'max', # mengambil tanggal order terakhir
    'order_id': 'nunique', # mengambil jumlah order
    'total_price': 'sum' # mengambil total revenue yang dihasilkan
})
rfm_df.head()
# Out:
#    customer_id order_date  order_id  total_price
# 0            1 2021-04-04         3         1641
# 1            7 2021-05-21         1         1017
# 2           10 2021-03-09         1          270
# 3           11 2021-05-28         1          382
# 4           12 2021-06-19         1         1551

# %% [markdown]
# Kita rename nama kolom nya biar lebih sesuai sama data yang baru.

# %%
rfm_df.columns = ['customer_id', 'max_order_timestamp', 'frequency', 'monetary']
rfm_df.head()
# Out:
#    customer_id max_order_timestamp  frequency  monetary
# 0            1          2021-04-04          3      1641
# 1            7          2021-05-21          1      1017
# 2           10          2021-03-09          1       270
# 3           11          2021-05-28          1       382
# 4           12          2021-06-19          1      1551

# %% [markdown]
# Selanjutnya kita hitung kapan terakhir pelanggan melakukan transaksi (dalam satuan hari)

# %%
rfm_df['max_order_timestamp'] = rfm_df['max_order_timestamp'].dt.date
recent_date = orders_df['order_date'].dt.date.max()
rfm_df['recency'] = rfm_df['max_order_timestamp'].apply(lambda x: (recent_date - x).days)
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          3      1641      203
# 1            7          1      1017      156
# 2           10          1       270      229
# 3           11          1       382      149
# 4           12          1      1551      127

# %% [markdown]
# Dataframe sudah siap. Sekarang kita bisa visualisasikan best customer berdasarkan parameter frequency, monetary, dan recency menggunakan kode berikut.

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30,6))

colors=["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(
    y='recency',
    x='customer_id',
    data=rfm_df.sort_values(by='recency', ascending=True).head(),
    palette=colors,
    ax=ax[0]
)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title('By Recency (days)', loc='center', fontsize=18)

sns.barplot(
    y='frequency',
    x='customer_id',
    data=rfm_df.sort_values(by='frequency', ascending=False).head(),
    palette=colors,
    ax=ax[1]
)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title('By Frequency', loc='center', fontsize=18)

sns.barplot(
    y='monetary',
    x='customer_id',
    data=rfm_df.sort_values(by='monetary', ascending=False).head(),
    palette=colors,
    ax=ax[2]
)
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title('By Monetary', loc='center', fontsize=18)

plt.suptitle('Best Customer Based on RFM Parameters (customer_id)', fontsize=20)

plt.show()
# Out:
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2242543243.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2242543243.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Bella\AppData\Local\Temp\ipykernel_3964\2242543243.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# INSIGHT: Dari visualisasi data di atas, kita dapat melihat beberapa pelanggan terbaik berdasarkan ketiga parameter tersebut. Informasi ini tentunya dapat membantu kita dalam menjawab tiga pertanyaan analisis terakhir.
